# %%
import pandas as pd

# %% [markdown]
# ### 参考URL
# https://code.i-harness.com/ja/q/2083365

# %%
df = pd.read_csv('stopsignannotations.txt', header=None, sep=' ')
df.columns = ['filename', 'obj_name', 'xmax', 'xmin', 'ymax', 'ymin']
df.head()
# Out:
#             filename  obj_name  xmax  xmin  ymax  ymin
# 0  stop_sign-001.jpg         1     8     7   147   120
# 1  stop_sign-002.jpg         1     4     7   392   382
# 2  stop_sign-003.jpg         1   193   134   227   201
# 3  stop_sign-004.jpg         1    78    30   144   123
# 4  stop_sign-005.jpg         1     7    35   323   279

# %%
import matplotlib
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %%
#枠が正しいか確認
import numpy as np
from PIL import *
from matplotlib import patches

im = np.array(Image.open('img/stop_sign-003.jpg'), dtype=np.uint8)

# Create figure and axes
fig,ax = plt.subplots(1)

# Display the image
ax.imshow(im)

# Create a Rectangle patch
rect = patches.Rectangle((193,134),227,201,linewidth=1,edgecolor='r',facecolor='none')
# Add the patch to the Axes
ax.add_patch(rect)

plt.show()

# %%
cv2.rectangle(img,(8,7),(155,127),(0,255,0),3)
cv2.imshow("img", img)

# matplotlibを使った方法
# fig = plt.figure()
# ax = fig.add_subplot(111)
# rect = plt.Rectangle((8,7),147,120,fc="#770000")
# img.add_patch(rect)

# plt.show()

# %%
df['obj_name'] = 'Stopsign'

# %%
#データをエクスポート
# df.to_csv("test.csv")

# %%
item {
  id: 1
  name: 'aeroplane'
}
